# %%
import tensorflow as tf

# %%
gen = tf.keras.models.load_model("Unet-gen-of-GAN.h5")
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1205 12:37:19.462835 140179051951936 hdf5_format.py:171] No training configuration found in save file: the model was *not* compiled. Compile it manually.

# %%
tf.keras.utils.plot_model(gen,to_file="gen-unet.png",show_shapes=True)

# %%
dis = tf.keras.models.load_model("dis-of-GAN.h5")

# %%
tf.keras.utils.plot_model(dis, to_file="dis-gan.png",show_shapes=True)
